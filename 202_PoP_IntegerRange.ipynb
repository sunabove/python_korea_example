# %%
# 정수 표현 범위

a = 1
while 1 :
    print( "\b"*len(f"{a}"), end="" )
    print( f"{a}", end="" )
    a += 1
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 a = 1
#       4 while 1 :
# ----> 5     print( "\b"*len(f"{a}"), end="" )
#       6     print( f"{a}", end="" )
#       7     a += 1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:577, in OutStream._schedule_flush(self)
#     573 @property
#     574 def closed(self):
#     575     return self.pub_thread is None
# --> 577 def _schedule_flush(self):
#     578     """schedule a flush in the IO thread
#     579
#     580     call this on write, to indicate that flush should be called soon.
#     581     """
# ...
